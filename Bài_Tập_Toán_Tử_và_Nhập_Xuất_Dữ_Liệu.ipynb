# %% [markdown]
# <a href="https://colab.research.google.com/github/phammanhcuong32115147-afk/PhamManhCuong_25021510_TDTT/blob/main/B%C3%A0i_T%E1%BA%ADp_To%C3%A1n_T%E1%BB%AD_v%C3%A0_Nh%E1%BA%ADp_Xu%E1%BA%A5t_D%E1%BB%AF_Li%E1%BB%87u.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World!')

# %%
a = input('Nhập tên người dùng:')
print('Chào',a)

# %%
a,b = map(int,input().split())
print(a+b)
print(a-b)
print(a*b)
print(a//b)
print(a%b)
print(f'{a/b:.2f}')

# %%
a1,b1,c1,a2,b2,a3 = map(int,input().split())
tb = (a1+b1+c1+(a2+b2)*2+a3*3)/10
print(f'{tb:.1f}')

# %%
a,b = map(int,input().split())
print(a**b)

# %%
a = input()
print(ord(a))
print(a.upper())

# %%
print((13**2)*3+5)
print(13**2*3+5)

# %%
c = int(input())
f = (9/5)*c+32
print(f'{f:.2f}')

# %%
x = int(input())
tien = x + 10 +x*0.3+x*0.1
print(f'{tien:.2f}')

# %%
a = input()
b = a.split()
print('Hi ' + b[2] + ', ' + b[1] + ' and '+ b[0])

# %%
a,b = map(int,input().split())
print(a*3600+b*60)
# Out:
# 1 30
# 5400

# %%
n = int(input())
print(n*n*6)

# %%
a,b = map(int,input().split())
print((a*b)%10)

# %%
a,b = map(int,input().split())
a,b =b,a
print(a,b)
# Out:
# 1 2
# 2 1

# %%
n = int(input())
sosao = 6*n*(n-1)+1
print(sosao)

# %%
print('Spring\nSummer\nAutumn\nWinter')

# %%
print('*','*'*2,'*'*3,sep='\n')
# Out:
# *
# **
# ***

# %%
print("### ##   ### ###")
print(" #  # #   #   #")
print(" #  # #   #   #")
print(" #  # #   #   #")
print(" #  ##    #   #")
# Out:
# ### ##   ### ###
#  #  # #   #   #
#  #  # #   #   #
#  #  # #   #   #
#  #  ##    #   #

# %%
print("Monday")
print("Tuesday")
print("Wednesday")
print("Thursday")
print("Friday")
print("Saturday")
print("Sunday")

# %%
print("January")
print("February")
print("March")
print("April")
print("May")
print("June")
print("July")
print("August")
print("September")
print("October")
print("November")
print("December")

# %%
print('Hello, world\n'*10)
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
